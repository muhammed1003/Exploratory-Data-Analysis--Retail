# %% [markdown]
# # The Sparks Foundation - Data Science & Business Analytics Internship
#
# ## Task 3 - Exploratory Data Analysis - Retail
#
# ### A Exploratory Data Analysis on Sample Superstore using python on jupter notebook
#
# #### Data set Url - https://bit.ly/3i4rbWl
#
# ##### Batch : November, 2022
#
# ## Author : Mohammed A. Rufai

# %%
# import the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Load the dataset
df=pd.read_csv("SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# check if there is any missing value in any column
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# check the data types of the columns
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
# drop duplicate values
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
# Get the count of the unique values of a column
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
# drop postal code column as it is of no use
df= df.drop ('Postal Code', axis=1)
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
# get the column names from the dataframe
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# get the correlation btw variables
df.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
# get the covariance btw the variables
df.cov()
# Out:
#                   Sales    Quantity   Discount        Profit
# Sales     388434.455308  278.459923  -3.627228  69944.096586
# Quantity     278.459923    4.951113   0.003961     34.534769
# Discount      -3.627228    0.003961   0.042622    -10.615173
# Profit     69944.096586   34.534769 -10.615173  54877.798055

# %%
# get the count of unique values from the region columns 
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
sns.set_style ('whitegrid')
sns.countplot(df['Region'],
order=df['Region'].value_counts().index)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
#get the count of unique values from the state columns
df['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(20,9))
plt.xticks(rotation=90)
sns.set_style('whitegrid')
sns.countplot(df['State'],
order=df['State'].value_counts().index)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='State', ylabel='count'>

# %%
# get the count of unique values from the city column
city=df['City'].value_counts()
city.head(10)
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Houston          377
# Chicago          314
# Columbus         222
# San Diego        170
# Springfield      163
# Name: City, dtype: int64

# %%
sns.set_style('whitegrid')
sns.countplot(x=df['Category'],
order=df['Category'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
sns.set_style('whitegrid')
sns.countplot(df['Sub-Category'],
order=df['Sub-Category'].value_counts().index)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sub-Category', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(df['Segment'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
sns.set_style('whitegrid') 
sns.barplot(x=df['Sub-Category'],y=df['Sales'])
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Sales'>

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
sns.set_style('whitegrid') 
sns.barplot(x=df['State'],y=df['Profit'])
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
top10cities=df.groupby('City')['Sales'].sum().sort_values(ascending=False).iloc[0:10]
plt.title('Sales of Top 10 cities')
plt.xlabel('city')
plt.ylabel('Total sum of sales')
top10cities.plot(kind='bar')
# Out:
# <AxesSubplot:title={'center':'Sales of Top 10 cities'}, xlabel='City', ylabel='Total sum of sales'>

# %%
top10states=df.groupby('State')['Quantity'].sum().sort_values(ascending=False).iloc[0:10]
plt.title('Sales of Top 10 states')
plt.xlabel('city')
plt.ylabel('Total sum of sales')
top10states.plot(kind='bar')
# Out:
# <AxesSubplot:title={'center':'Sales of Top 10 states'}, xlabel='State', ylabel='Total sum of sales'>

# %%
# count of discount sales grouped by city
discount=df.groupby('City')['Discount'].value_counts().sort_values(ascending=False).iloc[0:10]
discount
# Out:
# City           Discount
# New York City  0.0         650
# Los Angeles    0.0         466
# San Francisco  0.0         336
# Philadelphia   0.2         326
# Seattle        0.0         289
# Los Angeles    0.2         267
# Houston        0.2         210
# New York City  0.2         180
# Chicago        0.2         178
# San Francisco  0.2         158
# Name: Discount, dtype: int64

# %%
# statewise sales and profit overview
overview=df.groupby('State')['Profit','Sales'].sum()
overview.plot(kind='bar',figsize=(25,8))
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_8256\2325830269.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   overview=df.groupby('State')['Profit','Sales'].sum()
# <AxesSubplot:xlabel='State'>
